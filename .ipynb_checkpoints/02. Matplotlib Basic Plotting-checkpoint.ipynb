# %% [markdown]
# # 2. Matplotlib Data Plotting
#
# ### Objectives
# * Use the Axes plotting methods to make basic line and scatter plots
# * Learn how to change the appearance of the plot by modifying properties such as linestyle, color, marker, and more
#
# ### Introduction
# In the previous notebook, we created Figure and Axes objects, and proceeded to change their properties without plotting any actual data. In this notebook, we will learn how to make basic line and scatter plots with the Axes object.
#
# ### The Axes API
# The [matplotlib documentation][1] has a very nice layout of the Axes API. There are around 300 different calls you make with an Axes object. The API page categories and groups each method by its functionality. The first third (approximately) of the categories in the API are used to create plots.
#
# The simplest and most common plots are found in the **Basics** category and include **`plot`**, **`scatter`**, **`bar`**, **`pie`**, and others.
#
# [1]: https://matplotlib.org/api/axes_api.html

# %% [markdown]
# ## Creating a single Axes in a Figure
# If you do not specify the number of rows or columns in the call to the **`subplots`** function, a single Axes will be created inside of a Figure. A NumPy array will not be returned like we saw in the last notebook, but instead, an Axes will be. Let's see an example of this.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ## The `plot` method - Creates line plots
# As usual, the bulk of the work will come from the Axes object. You will mainly be calling methods with it. The **`plot`** method's primary purpose is to create **line plots**. It does have the ability to create scatter plots as well, but that task is best reserved for **`scatter`**.
#
# ### Plotting 2D Data
# The **`plot`** method is very flexible and can take on a variety of different inputs. The following teaches a straightforward and consistent approach that is explicit and easy to read.
#
# The first two arguments to the **`plot`** method can be the x and y coordinates of the data. Below, we use NumPy arrays to hold our data. We simply plot the square of the x value.

# %%
x = np.arange(-10, 10)
y = x**2+2*x-5
ax.plot(x, y)

# %% [markdown]
# ### What was returned?
# As usual, no image was produced. The figure got updated, but you must explicitly put its name as the last line in your cell to have it output to the screen.
#
# A list of `Line` objects were returned from our call to the **`plot`** method. The **`plot`** method can produce many lines in a single call to it, which is why it returns the results as a list. Let's output our Figure, revealing the line plot.

# %%
fig

# %%
fig,ax = plt.subplot(figsize=)

# %% [markdown]
# ## Formatting the line
# The line can be formatted using many different parameters. Please see the documentation for the [Line object][1]. All of the possible parameters are available on that page.
#
# [1]: https://matplotlib.org/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D

# %% [markdown]
# ## Use Pandas to scrape the html table

# %%
pd.options.display.max_colwidth = 300

# %%
dfs = pd.read_html('https://matplotlib.org/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D')
dfs[0]
# Out:
#               Property  \
# 0           agg_filter
# 1                alpha
# 2             animated
# 3          antialiased
# 4             clip_box
# 5              clip_on
# 6            clip_path
# 7                color
# 8             contains
# 9        dash_capstyle
# 10      dash_joinstyle
# 11              dashes
# 12           drawstyle
# 13              figure
# 14           fillstyle
# 15                 gid
# 16           in_layout
# 17               label
# 18           linestyle
# 19           linewidth
# 20              marker
# 21     markeredgecolor
# 22     markeredgewidth
# 23     markerfacecolor
# 24  markerfacecoloralt
# 25          markersize
# 26           markevery
# 27        path_effects
# 28              picker
# 29          pickradius
# 30          rasterized
# 31       sketch_params
# 32                snap
# 33      solid_capstyle
# 34     solid_joinstyle
# 35           transform
# 36                 url
# 37             visible
# 38               xdata
# 39               ydata
# 40              zorder
#
#                                                                                               Description
# 0   a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
# 1                                                                                                   float
# 2                                                                                                    bool
# 3                                                                                                    bool
# 4                                                                                                    Bbox
# 5                                                                                                    bool
# 6                                                                      [(Path, Transform) | Patch | None]
# 7                                                                                                   color
# 8                                                                                                callable
# 9                                                                         {'butt', 'round', 'projecting'}
# 10                                                                            {'miter', 'round', 'bevel'}
# 11                                              sequence of floats (on/off ink in points) or (None, None)
# 12                                           {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}
# 13                                                                                                 Figure
# 14                                                     {'full', 'left', 'right', 'bottom', 'top', 'none'}
# 15                                                                                                    str
# 16                                                                                                   bool
# 17                                                                                                 object
# 18                                                  {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
# 19                                                                                                  float
# 20                                                                                                unknown
# 21                                                                                                  color
# 22                                                                                                  float
# 23                                                                                                  color
# 24                                                                                                  color
# 25                                                                                                  float
# 26                                                                                                unknown
# 27                                                                                     AbstractPathEffect
# 28                                                  float or callable[[Artist, Event], Tuple[bool, dict]]
# 29                                                                                                  float
# 30                                                                                           bool or None
# 31                                                       (scale: float, length: float, randomness: float)
# 32                                                                                           bool or None
# 33                                                                        {'butt', 'round', 'projecting'}
# 34                                                                            {'miter', 'round', 'bevel'}
# 35                                                                        matplotlib.transforms.Transform
# 36                                                                                                    str
# 37                                                                                                   bool
# 38                                                                                               1D array
# 39                                                                                               1D array
# 40                                                                                                  float

# %% [markdown]
# ### Change line style
# Look at the documentation above and change the line style. The default is solid. If you don't recreate the figure, the old line will still remain.

# %%
fig, ax = plt.subplots()
ax.plot(x, y, linestyle='--')

# %% [markdown]
# ### Remove all the objects from the Axes with `clear`

# %%
ax.clear()
fig

# %% [markdown]
# # Matplotlib Colors
#
# There are many possible ways to identify a color in matplotlib. Read the [color documentation][1] to see all 8 ways to specify a color.
#
# * an RGB or RGBA tuple of float values in [0, 1] (e.g., (0.1, 0.2, 0.5) or (0.1, 0.2, 0.5, 0.3)). RGBA is short for Red, Green, Blue, Alpha;
# * a hex RGB or RGBA string (e.g., '#0F0F0F' or '#0F0F0F0F');
# * a string representation of a float value in [0, 1] inclusive for gray level (e.g., '0.5');
# * one of {'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'}; **I don't use these because they are confusing**
# * a X11/CSS4 color name - **I do use these**
#
# ### Web Colors
# You can use any of the following colors that are available to web developers in CSS - a language that styles web pages.
# ![][2]
#
# [1]: https://matplotlib.org/tutorials/colors/colors.html#sphx-glr-tutorials-colors-colors-py
# [2]: images/named_colors.png

# %% [markdown]
# # Integration with Pandas - plotting real data
# # Matplotlib makes it simple to create plots when our data is in a DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 100
fl = pd.read_csv('../data/flights.csv')
fl.head()
# Out:
#    year  month  day  day_of_week airline  flight_number tail_number  \
# 0  2015      1    1            4      WN           1908      N8324A
# 1  2015      1    1            4      UA            581      N448UA
# 2  2015      1    1            4      MQ           2851      N645MQ
# 3  2015      1    1            4      AA            383      N3EUAA
# 4  2015      1    1            4      WN           3047      N560WN
#
#   origin_airport destination_airport  scheduled_departure  departure_time  \
# 0            LAX                 SLC                 1625          1723.0
# 1            DEN                 IAD                  823           830.0
# 2            DFW                 VPS                 1305          1341.0
# 3            DFW                 DCA                 1555          1602.0
# 4            LAX                 MCI                 1720          1808.0
#
#    departure_delay  taxi_out  wheels_off  scheduled_time  elapsed_time  \
# 0             58.0      10.0      1733.0           100.0         107.0
# 1              7.0      11.0       841.0           190.0         170.0
# 2             36.0      18.0      1359.0           108.0         107.0
# 3              7.0      13.0      1615.0           160.0         146.0
# 4             48.0       6.0      1814.0           185.0         176.0
#
#    air_time  distance  wheels_on  taxi_in  scheduled_arrival  arrival_time  \
# 0      94.0       590     2007.0      3.0               1905        2010.0
# 1     154.0      1452     1315.0      5.0               1333        1320.0
# 2      85.0       641     1524.0      4.0               1453        1528.0
# 3     126.0      1192     1921.0      7.0               1935        1928.0
# 4     166.0      1363     2300.0      4.0               2225        2304.0
#
#    arrival_delay  diverted  cancelled cancellation_reason  air_system_delay  \
# 0           65.0         0          0                 NaN              31.0
# 1          -13.0         0          0                 NaN               NaN
# 2           35.0         0          0                 NaN               0.0
# 3           -7.0         0          0                 NaN               NaN
# 4           39.0         0          0                 NaN               0.0
#
#    security_delay  airline_delay  late_aircraft_delay  weather_delay
# 0             0.0            0.0                 34.0            0.0
# 1             NaN            NaN                  NaN            NaN
# 2             0.0           35.0                  0.0            0.0
# 3             NaN            NaN                  NaN            NaN
# 4             0.0           17.0                 22.0            0.0

# %% [markdown]
# ### Let's first get find the average delay for each month.

# %%
month_delay = fl.groupby('month', as_index=False).agg({'departure_delay': ['mean', 'size']})
month_delay.columns = ['month', 'average delay', 'count']
month_delay
# Out:
#     month  average delay  count
# 0       1      11.044667   5003
# 1       2      11.314085   4608
# 2       3      10.895663   5485
# 3       4       8.872772   5326
# 4       5      11.241133   5545
# 5       6      15.926112   5672
# 6       7      12.934268   5754
# 7       8      10.596212   5635
# 8       9       5.631609   5235
# 9      11       8.632673   5098
# 10     12      12.593032   5131

# %% [markdown]
# ### Make a line plot with a DataFrame
# Matplotlib simplifies the process by providing a **`data`** parameter. Set this equal to the name of the DataFrame. Put the column names as strings as the first two parameters in the **`plot`** method.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot('month', 'average delay', data=month_delay, marker='s')
ax.set_xlabel('Month', fontsize=15)
ax.set_title('Average Delay', fontsize=20, color='tomato')
# Out:
# Text(0.5,1,'Average Delay')

# %% [markdown]
# ### Grayscale
# Use a **string** with a number between 0 and 1 for grayscale.

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color='.7')

# %% [markdown]
# ## Markers
# There are a few dozen [styles for markers][1]. These are plotted on every point. Use a string to reference the one you want.
#
# [1]: https://matplotlib.org/api/markers_api.html

# %%
dfs = pd.read_html('https://matplotlib.org/api/markers_api.html')
dfs[0]
# Out:
#                       marker  symbol  \
# 0                        "."     NaN
# 1                        ","     NaN
# 2                        "o"     NaN
# 3                        "v"     NaN
# 4                        "^"     NaN
# 5                        "<"     NaN
# 6                        ">"     NaN
# 7                        "1"     NaN
# 8                        "2"     NaN
# 9                        "3"     NaN
# 10                       "4"     NaN
# 11                       "8"     NaN
# 12                       "s"     NaN
# 13                       "p"     NaN
# 14                       "P"     NaN
# 15                       "*"     NaN
# 16                       "h"     NaN
# 17                       "H"     NaN
# 18                       "+"     NaN
# 19                       "x"     NaN
# 20                       "X"     NaN
# 21                       "D"     NaN
# 22                       "d"     NaN
# 23                       "|"     NaN
# 24                       "_"     NaN
# 25              0 (TICKLEFT)     NaN
# 26             1 (TICKRIGHT)     NaN
# 27                2 (TICKUP)     NaN
# 28              3 (TICKDOWN)     NaN
# 29             4 (CARETLEFT)     NaN
# 30            5 (CARETRIGHT)     NaN
# 31               6 (CARETUP)     NaN
# 32             7 (CARETDOWN)     NaN
# 33         8 (CARETLEFTBASE)     NaN
# 34        9 (CARETRIGHTBASE)     NaN
# 35          10 (CARETUPBASE)     NaN
# 36        11 (CARETDOWNBASE)     NaN
# 37         "None", " " or ""     NaN
# 38                   '$...$'     NaN
# 39                     verts     NaN
# 40                      path     NaN
# 41  (numsides, style, angle)     NaN
#
#                                           description
# 0                                               point
# 1                                               pixel
# 2                                              circle
# 3                                       triangle_down
# 4                                         triangle_up
# 5                                       triangle_left
# 6                                      triangle_right
# 7                                            tri_down
# 8                                              tri_up
# 9                                            tri_left
# 10                                          tri_right
# 11                                            octagon
# 12                                             square
# 13                                           pentagon
# 14                                      plus (filled)
# 15                                               star
# 16                                           hexagon1
# 17                                           hexagon2
# 18                                               plus
# 19                                                  x
# 20                                         x (filled)
# 21                                            diamond
# 22                                       thin_diamond
# 23                                              vline
# 24                                              hline
# 25                                           tickleft
# 26                                          tickright
# 27                                             tickup
# 28                                           tickdown
# 29                                          caretleft
# 30                                         caretright
# 31                                            caretup
# 32                                          caretdown
# 33                       caretleft (centered at base)
# 34                      caretright (centered at base)
# 35                         caretup (centered at base)
# 36                       caretdown (centered at base)
# 37                                            nothing
# 38  Render the string using mathtext. E.g "$f$" fo...
# 39  A list of (x, y) pairs used for Path vertices....
# 40                                   A Path instance.
# 41  The marker can also be a tuple (numsides, styl...

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color='darkred', linestyle='--', marker='s')

# %% [markdown]
# ## Remove the line with a blank string

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color='darkred', linestyle='', marker='x')

# %% [markdown]
# A few more parameters.

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color='darkred',
              linestyle='--',
              linewidth=4,
              marker='D',
              markerfacecolor='blue',
              markersize=15)

# %% [markdown]
# # Integration with Pandas - plotting real data
# Matplotlib makes it quite simple to create some plots when our data is in a Pandas DataFrame.

# %%
pd.options.display.max_columns = 100
fl = pd.read_csv('../data/flights.csv')
fl.head()
# Out:
#    year  month  day  day_of_week airline  flight_number tail_number  \
# 0  2015      1    1            4      WN           1908      N8324A
# 1  2015      1    1            4      UA            581      N448UA
# 2  2015      1    1            4      MQ           2851      N645MQ
# 3  2015      1    1            4      AA            383      N3EUAA
# 4  2015      1    1            4      WN           3047      N560WN
#
#   origin_airport destination_airport  scheduled_departure  departure_time  \
# 0            LAX                 SLC                 1625          1723.0
# 1            DEN                 IAD                  823           830.0
# 2            DFW                 VPS                 1305          1341.0
# 3            DFW                 DCA                 1555          1602.0
# 4            LAX                 MCI                 1720          1808.0
#
#    departure_delay  taxi_out  wheels_off  scheduled_time  elapsed_time  \
# 0             58.0      10.0      1733.0           100.0         107.0
# 1              7.0      11.0       841.0           190.0         170.0
# 2             36.0      18.0      1359.0           108.0         107.0
# 3              7.0      13.0      1615.0           160.0         146.0
# 4             48.0       6.0      1814.0           185.0         176.0
#
#    air_time  distance  wheels_on  taxi_in  scheduled_arrival  arrival_time  \
# 0      94.0       590     2007.0      3.0               1905        2010.0
# 1     154.0      1452     1315.0      5.0               1333        1320.0
# 2      85.0       641     1524.0      4.0               1453        1528.0
# 3     126.0      1192     1921.0      7.0               1935        1928.0
# 4     166.0      1363     2300.0      4.0               2225        2304.0
#
#    arrival_delay  diverted  cancelled cancellation_reason  air_system_delay  \
# 0           65.0         0          0                 NaN              31.0
# 1          -13.0         0          0                 NaN               NaN
# 2           35.0         0          0                 NaN               0.0
# 3           -7.0         0          0                 NaN               NaN
# 4           39.0         0          0                 NaN               0.0
#
#    security_delay  airline_delay  late_aircraft_delay  weather_delay
# 0             0.0            0.0                 34.0            0.0
# 1             NaN            NaN                  NaN            NaN
# 2             0.0           35.0                  0.0            0.0
# 3             NaN            NaN                  NaN            NaN
# 4             0.0           17.0                 22.0            0.0

# %% [markdown]
# Let's first get find the average delay for each month.

# %%
airt= fl.groupby(['month', 'airline'], as_index=False).agg({'air_time': ['mean', 'size']})
airt.columns = ['month',  'airline','average airtime', 'count']
airt
# Out:
#      month airline  average airtime  count
# 0        1      AA       138.793103    677
# 1        1      AS       149.727273     66
# 2        1      B6       191.956522     47
# 3        1      DL       116.238788    837
# 4        1      EV        72.410985    540
# 5        1      F9       120.910000    104
# 6        1      HA       337.562500     17
# 7        1      MQ        61.418539    380
# 8        1      NK       136.528926    122
# 9        1      OO        73.173285    572
# 10       1      UA       149.837838    604
# 11       1      US       142.256917    258
# 12       1      VX       134.305882     86
# 13       1      WN       106.969118    693
# 14       2      AA       143.126560    615
# 15       2      AS       150.229508     61
# 16       2      B6       198.088889     46
# 17       2      DL       111.725992    795
# 18       2      EV        69.532558    457
# 19       2      F9       119.052632     96
# 20       2      HA       355.222222      9
# 21       2      MQ        61.426471    314
# 22       2      NK       130.637255    107
# 23       2      OO        73.667283    563
# 24       2      UA       149.138840    583
# 25       2      US       149.177570    220
# 26       2      VX       140.987342     82
# 27       2      WN       101.603421    660
# 28       3      AA       142.026163    704
# 29       3      AS       142.707692     65
# ..     ...     ...              ...    ...
# 119      9      OO        77.166667    597
# 120      9      UA       153.231548    695
# 121      9      VX       176.191011     89
# 122      9      WN       109.842239    792
# 123     11      AA       139.170705    922
# 124     11      AS       148.750000     64
# 125     11      B6       213.869565     46
# 126     11      DL       113.592265    905
# 127     11      EV        66.869469    461
# 128     11      F9       126.080645    125
# 129     11      HA       346.625000      8
# 130     11      MQ        58.265957    288
# 131     11      NK       141.052980    154
# 132     11      OO        79.918626    562
# 133     11      UA       148.753228    700
# 134     11      VX       160.412371     97
# 135     11      WN       104.704244    766
# 136     12      AA       147.931111    916
# 137     12      AS       156.333333     69
# 138     12      B6       228.826923     53
# 139     12      DL       114.258836    964
# 140     12      EV        64.339408    457
# 141     12      F9       134.643411    131
# 142     12      HA       331.000000      8
# 143     12      MQ        59.205674    294
# 144     12      NK       137.098039    155
# 145     12      OO        83.393214    527
# 146     12      UA       156.592047    690
# 147     12      VX       150.459184     98
# 148     12      WN       104.136304    769
#
# [149 rows x 4 columns]

# %%
airt= fl.groupby(['airline'], as_index=False).agg({'air_time': ['mean', 'size']})
airt.columns = [ 'airline','average airtime', 'count']
airt
# Out:
#    airline  average airtime  count
# 0       AA       144.259404   8900
# 1       AS       147.845052    768
# 2       B6       209.412963    543
# 3       DL       115.334187  10601
# 4       EV        68.964016   5858
# 5       F9       127.592337   1317
# 6       HA       338.288288    112
# 7       MQ        61.318346   3471
# 8       NK       135.736878   1516
# 9       OO        76.010272   6588
# 10      UA       155.650521   7792
# 11      US       147.686755   1615
# 12      VX       154.864097    993
# 13      WN       107.005897   8418

# %%
aa = fl['airline'] == 'AA'
da= fl['airline'] == 'DL'
filt = aa | da
af = fl[filt]
af.head(20).round(3)
# Out:
#     year  month  day  day_of_week airline  flight_number tail_number  \
# 3   2015      1    1            4      AA            383      N3EUAA
# 6   2015      1    1            4      AA            975      N559AA
# 8   2015      1    1            4      AA           1634      N4WNAA
# 15  2015      1    1            4      AA           1151      N508AA
# 26  2015      1    1            4      AA           1188      N4XXAA
# 32  2015      1    1            4      AA            152      N3DHAA
# 33  2015      1    1            4      AA           2227      N016AA
# 36  2015      1    1            4      AA            382      N574AA
# 37  2015      1    1            4      AA           1528      N475AA
# 41  2015      1    1            4      AA           2472      N3ADAA
# 46  2015      1    1            4      AA            159      N3JHAA
# 47  2015      1    1            4      AA           1385      N4YAAA
# 48  2015      1    1            4      AA            296      N4XYAA
# 53  2015      1    1            4      DL           1550      N3739P
# 55  2015      1    1            4      AA           1181      N3FEAA
# 57  2015      1    1            4      DL           1925      N534US
# 62  2015      1    1            4      AA            380      N3HVAA
# 66  2015      1    1            4      AA           1600      N571AA
# 73  2015      1    1            4      AA           2377      N559AA
# 75  2015      1    1            4      AA           2325      N367AA
#
#    origin_airport destination_airport  scheduled_departure  departure_time  \
# 3             DFW                 DCA                 1555          1602.0
# 6             DFW                 MSY                 1250          1414.0
# 8             ORD                 STL                 1845          1840.0
# 15            DEN                 DFW                 1445          1439.0
# 26            LAX                 AUS                 1430          1503.0
# 32            PHX                 MIA                 1559          1754.0
# 33            IAH                 MIA                 1935          2001.0
# 36            DFW                 OKC                 1345          1350.0
# 37            LAS                 DFW                 1210          1222.0
# 41            DFW                 DCA                 2010          2029.0
# 46            ORD                 SAN                 1235          1229.0
# 47            DFW                 IND                 1625          1705.0
# 48            DFW                 SAT                 1725          1725.0
# 53            LAS                 MSP                  713           708.0
# 55            LAS                 DFW                 1535          1631.0
# 57            MSP                 RSW                  700           659.0
# 62            ORD                 LGA                 1040          1053.0
# 66            DFW                 AUS                 1710          1712.0
# 73            DFW                 ICT                 1000             NaN
# 75            DFW                 ORD                 1740          2249.0
#
#     departure_delay  taxi_out  wheels_off  scheduled_time  elapsed_time  \
# 3               7.0      13.0      1615.0           160.0         146.0
# 6              84.0      13.0      1427.0            80.0          79.0
# 8              -5.0      15.0      1855.0            65.0          65.0
# 15             -6.0      24.0      1503.0           120.0         130.0
# 26             33.0      20.0      1523.0           175.0         183.0
# 32            115.0      13.0      1807.0           244.0         246.0
# 33             26.0      16.0      2017.0           141.0         136.0
# 36              5.0      15.0      1405.0            55.0          56.0
# 37             12.0      23.0      1245.0           160.0         165.0
# 41             19.0      12.0      2041.0           160.0         145.0
# 46             -6.0      10.0      1239.0           260.0         250.0
# 47             40.0      15.0      1720.0           120.0         107.0
# 48              0.0      16.0      1741.0            65.0          74.0
# 53             -5.0      12.0       720.0           187.0         174.0
# 55             56.0      11.0      1642.0           160.0         153.0
# 57             -1.0      16.0       715.0           210.0         191.0
# 62             13.0      11.0      1104.0           120.0          98.0
# 66              2.0      13.0      1725.0            60.0          60.0
# 73              NaN       NaN         NaN            75.0           NaN
# 75            309.0      15.0      2304.0           135.0         113.0
#
#     air_time  distance  wheels_on  taxi_in  scheduled_arrival  arrival_time  \
# 3      126.0      1192     1921.0      7.0               1935        1928.0
# 6       64.0       447     1531.0      2.0               1410        1533.0
# 8       44.0       258     1939.0      6.0               1950        1945.0
# 15      93.0       641     1736.0     13.0               1745        1749.0
# 26     157.0      1242     2000.0      6.0               1925        2006.0
# 32     230.0      1972     2357.0      3.0               2203        2400.0
# 33     115.0       964     2312.0      5.0               2256        2317.0
# 36      35.0       175     1440.0      6.0               1440        1446.0
# 37     132.0      1055     1657.0     10.0               1650        1707.0
# 41     126.0      1192     2347.0      7.0               2350        2354.0
# 46     237.0      1723     1436.0      3.0               1455        1439.0
# 47      89.0       761     1949.0      3.0               1925        1952.0
# 48      54.0       247     1835.0      4.0               1830        1839.0
# 53     156.0      1299     1156.0      6.0               1220        1202.0
# 55     129.0      1055     2051.0     13.0               2015        2104.0
# 57     169.0      1416     1104.0      6.0               1130        1110.0
# 62      84.0       733     1328.0      3.0               1340        1331.0
# 66      43.0       190     1808.0      4.0               1810        1812.0
# 73       NaN       328        NaN      NaN               1115           NaN
# 75      91.0       802       35.0      7.0               1955          42.0
#
#     arrival_delay  diverted  cancelled cancellation_reason  air_system_delay  \
# 3            -7.0         0          0                 NaN               NaN
# 6            83.0         0          0                 NaN               0.0
# 8            -5.0         0          0                 NaN               NaN
# 15            4.0         0          0                 NaN               NaN
# 26           41.0         0          0                 NaN               8.0
# 32          117.0         0          0                 NaN               2.0
# 33           21.0         0          0                 NaN               0.0
# 36            6.0         0          0                 NaN               NaN
# 37           17.0         0          0                 NaN               5.0
# 41            4.0         0          0                 NaN               NaN
# 46          -16.0         0          0                 NaN               NaN
# 47           27.0         0          0                 NaN               0.0
# 48            9.0         0          0                 NaN               NaN
# 53          -18.0         0          0                 NaN               NaN
# 55           49.0         0          0                 NaN               0.0
# 57          -20.0         0          0                 NaN               NaN
# 62           -9.0         0          0                 NaN               NaN
# 66            2.0         0          0                 NaN               NaN
# 73            NaN         0          1                   B               NaN
# 75          287.0         0          0                 NaN               0.0
#
#     security_delay  airline_delay  late_aircraft_delay  weather_delay
# 3              NaN            NaN                  NaN            NaN
# 6              0.0            0.0                 83.0            0.0
# 8              NaN            NaN                  NaN            NaN
# 15             NaN            NaN                  NaN            NaN
# 26             0.0           15.0                 18.0            0.0
# 32             0.0          115.0                  0.0            0.0
# 33             0.0            0.0                 21.0            0.0
# 36             NaN            NaN                  NaN            NaN
# 37             0.0            4.0                  8.0            0.0
# 41             NaN            NaN                  NaN            NaN
# 46             NaN            NaN                  NaN            NaN
# 47             0.0            0.0                 20.0            7.0
# 48             NaN            NaN                  NaN            NaN
# 53             NaN            NaN                  NaN            NaN
# 55             0.0           49.0                  0.0            0.0
# 57             NaN            NaN                  NaN            NaN
# 62             NaN            NaN                  NaN            NaN
# 66             NaN            NaN                  NaN            NaN
# 73             NaN            NaN                  NaN            NaN
# 75             0.0           70.0                217.0            0.0

# %%
airt= af.groupby(['month', 'airline'], as_index=False).agg({'air_time': ['mean', 'size']})
airt.columns = [ 'month', 'airline','average airtime', 'count']
airt
# Out:
#     month airline  average airtime  count
# 0       1      AA       138.793103    677
# 1       1      DL       116.238788    837
# 2       2      AA       143.126560    615
# 3       2      DL       111.725992    795
# 4       3      AA       142.026163    704
# 5       3      DL       118.036597   1020
# 6       4      AA       144.544267    700
# 7       4      DL       115.314459    995
# 8       5      AA       145.261538    664
# 9       5      DL       114.810089   1017
# 10      6      AA       147.812329    744
# 11      6      DL       116.052156   1003
# 12      7      AA       145.608527   1044
# 13      7      DL       116.749509   1023
# 14      8      AA       147.289990    984
# 15      8      DL       119.270295   1086
# 16      9      AA       143.572354    930
# 17      9      DL       111.230126    956
# 18     11      AA       139.170705    922
# 19     11      DL       113.592265    905
# 20     12      AA       147.931111    916
# 21     12      DL       114.258836    964

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot('month', 'average delay', data=month_delay, marker='s')
ax.set_xlabel('Month', fontsize=15)
ax.set_title('Average Delay', fontsize=20, color='tomato')

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot('month', 'average airtime', data=airt, marker='s')
ax.set_xlabel('Month', fontsize=15)
ax.set_title('Avg Airtime', fontsize=20, color='purple')
# Out:
# Text(0.5,1,'Avg Airtime')

# %%
month_delay = fl.groupby('month', as_index=False).agg({'departure_delay': ['mean', 'size']})
month_delay.columns = ['month', 'average delay', 'count']
month_delay
# Out:
#     month  average delay  count
# 0       1      11.044667   5003
# 1       2      11.314085   4608
# 2       3      10.895663   5485
# 3       4       8.872772   5326
# 4       5      11.241133   5545
# 5       6      15.926112   5672
# 6       7      12.934268   5754
# 7       8      10.596212   5635
# 8       9       5.631609   5235
# 9      11       8.632673   5098
# 10     12      12.593032   5131

# %% [markdown]
# ### Make a line plot with a DataFrame
# Matplotlib simplifies the process by providing a **`data`** parameter. Set this equal to the name of the DataFrame. Put the column names as strings as the first two parameters in the **`plot`** method.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot('month', 'average delay', data=month_delay, marker='s')
ax.set_xlabel('Month', fontsize=15)
ax.set_title('Average Delay', fontsize=20, color='tomato')
# Out:
# Text(0.5,1,'Average Delay')

# %% [markdown]
# ## Remove the line with a blank string

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color='darkred', linestyle='', marker='x')

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color='darkred',
              linestyle='--',
              linewidth=4,
              marker='D',
              markerfacecolor='blue',
              markersize=15)

# %% [markdown]
# # Most common Plots
# Visit the [Axes API][1] to see the most common plotting methods.
#
# [1]: https://matplotlib.org/api/axes_api.html

# %%
dfs = pd.read_html('https://matplotlib.org/api/axes_api.html', r'Axes[.]plot')
axes_api = dfs[0]
axes_api.columns = ['Plotting Method', 'Description']
axes_api
# Out:
#        Plotting Method                                        Description
# 0            Axes.plot           Plot y versus x as lines and/or markers.
# 1        Axes.errorbar  Plot y versus x as lines and/or markers with a...
# 2         Axes.scatter  A scatter plot of y vs x with varying marker s...
# 3       Axes.plot_date                     Plot data that contains dates.
# 4            Axes.step                                  Make a step plot.
# 5          Axes.loglog  Make a plot with log scaling on both the x and...
# 6        Axes.semilogx        Make a plot with log scaling on the x axis.
# 7        Axes.semilogy        Make a plot with log scaling on the y axis.
# 8    Axes.fill_between       Fill the area between two horizontal curves.
# 9   Axes.fill_betweenx         Fill the area between two vertical curves.
# 10            Axes.bar                                   Make a bar plot.
# 11           Axes.barh                        Make a horizontal bar plot.
# 12           Axes.stem                                Create a stem plot.
# 13      Axes.eventplot  Plot identical parallel lines at the given pos...
# 14            Axes.pie                                  Plot a pie chart.
# 15      Axes.stackplot                          Draw a stacked area plot.
# 16    Axes.broken_barh          Plot a horizontal sequence of rectangles.
# 17         Axes.vlines                               Plot vertical lines.
# 18         Axes.hlines  Plot horizontal lines at each y from xmin to x...
# 19           Axes.fill                              Plot filled polygons.

# %% [markdown]
# ## Univariate Analysis
# These are the primary plots that you will make from your Axes. We just plotted a line with **`plot`** in our above example. Let's see a few more plots in action.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.boxplot(x=flights['taxi_out'].dropna())
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1260db2b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1260dbcc0>,
#   <matplotlib.lines.Line2D at 0x1260e1128>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1260e1978>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1260e1550>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1260db400>,
#   <matplotlib.lines.Line2D at 0x1260db898>]}

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.boxplot(x=flights['taxi_out'].dropna(), vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x12484b390>],
#  'caps': [<matplotlib.lines.Line2D at 0x12484bda0>,
#   <matplotlib.lines.Line2D at 0x124854208>],
#  'fliers': [<matplotlib.lines.Line2D at 0x124854a58>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x124854630>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x12484b4e0>,
#   <matplotlib.lines.Line2D at 0x12484b978>]}

# %% [markdown]
# ## Common Plots
# These are the primary plots that you will make from your Axes. We just plotted a line with **`plot`** in our above example. Let's see a few more plots in action.

# %% [markdown]
# ## Plotting dates
# The **`plot_date`** function creates a line or scatter plot with dates in the x-axis.

# %% [markdown]
# ### Read in the bikes dataset

# %%
bikes = pd.read_csv('../data/bikes.csv', parse_dates=['starttime', 'stoptime'])
bikes.head()
# Out:
#    trip_id    usertype gender           starttime            stoptime  \
# 0     7147  Subscriber   Male 2013-06-28 19:01:00 2013-06-28 19:17:00
# 1     7524  Subscriber   Male 2013-06-28 22:53:00 2013-06-28 23:03:00
# 2    10927  Subscriber   Male 2013-06-30 14:43:00 2013-06-30 15:01:00
# 3    12907  Subscriber   Male 2013-07-01 10:05:00 2013-07-01 10:16:00
# 4    13168  Subscriber   Male 2013-07-01 11:16:00 2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# 1       -87.641170              31.0     Wells St & Walton St     41.899930
# 2       -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 3       -87.653449              19.0   Clark St & Randolph St     41.884576
# 4       -87.677692              19.0   Damen Ave & Pierce Ave     41.909396
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 2     -87.629521            23.0         73.0        10.0        16.1
# 3     -87.631890            31.0         72.0        10.0        16.1
# 4     -87.677692            19.0         73.0        10.0        17.3
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 2        -9999.0  mostlycloudy
# 3        -9999.0  mostlycloudy
# 4        -9999.0  partlycloudy

# %% [markdown]
# ### Examine relationship between date and temperature

# %%
bikes['temperature'].describe()
# Out:
# count    50089.000000
# mean        62.608237
# std         48.151252
# min      -9999.000000
# 25%         52.000000
# 50%         66.900000
# 75%         75.900000
# max         96.100000
# Name: temperature, dtype: float64

# %%
bikes['temperature'].sort_values().head()
# Out:
# 27168   -9999.0
# 35073      -8.0
# 2064       -8.0
# 10262      -6.0
# 35074      -6.0
# Name: temperature, dtype: float64

# %% [markdown]
# Remove bad temperature data and sample 2% of the bikes dataset, which will help keep the number of plotted points from overwhelming the graph.

# %%
bikes = bikes[bikes['temperature'] > -10]
bikes2 = bikes.sample(frac=.02)

# %% [markdown]
# Call the **`plot_date`** function.

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('starttime', 'temperature', data=bikes2)

# %% [markdown]
# ## Plotting the Number of Riders per Day
# Let's find the number of riders each day. We need to group by each day.

# %%
temperature_count = bikes.resample('D', on='starttime').size()
temperature_count = temperature_count.reset_index()
temperature_count.head()

# %%
temperature_count.columns = ['starttime', 'count']
temperature_count.head()

# %%
fig, ax = plt.subplots(figsize=(14, 10))
ax.plot_date('starttime', 'count', data=temperature_count)
ax.set_title('Rider Count per Day', fontsize=30)

# %% [markdown]
# ##  Scatterplots
# Although we have already created some scatterplots above, Matplotlib has a special **`scatter`** function that allows you to set both the color and size of each point individually based on the value of a different variable.

# %%
diamonds = pd.read_csv('../data/diamonds.csv')
diamonds.head()

# %%
diamonds.shape

# %% [markdown]
# ## Color by diamond clarity - Turn to categorical variable first

# %%
diamonds[['clarity', 'color']] = diamonds[['clarity', 'color']].astype('category')
diamonds.dtypes

# %% [markdown]
# Show the underlying integer code and the category for each.

# %%
clarity = diamonds['clarity']
clarity.cat.codes.head()

# %%
clarity.cat.categories

# %%
diamonds['marker_colors'] = clarity.cat.codes / len(clarity.cat.categories)
diamonds.head()

# %%
cmap = plt.get_cmap('plasma')
fig, ax = plt.subplots(figsize=(14, 6))
dia_samp = diamonds.sample(frac=.02, random_state=1)
uniq_clarity = dia_samp['clarity'].unique()
uniq_colors = dia_samp['marker_colors'].unique()

for clar, col in zip(uniq_clarity, uniq_colors):
    filt = dia_samp['clarity'] == clar
    cur_data = dia_samp[filt]
    ax.scatter('carat', 'price', data=cur_data, marker='o', c=cmap(col), label=clar)
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend()

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">Create a Figure with three Axes using **`plt.subplots`**. Use **`np.linspace`** to create a one dimensional array of data from -5 to 5 of length 100 and store this to **`x`**. In each of three Axes, plot take some mathematical function of **`x`** to create **`y`** values in a line plot. For instance, you can take the square root of **`x`**.</span>

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Use **`np.random.rand`** to create two arrays, **`x`** and **`y`** that are each 100 units in length. Make a scatter plot of the data. Make the size of the markers proportional to the ratio of y to x. Make the color proportional to y. For scatter plots, use the parameter **`c`** to control the color with a number. The parameter **`s`** controls the size. Set the title as well.</span>

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Read in the college dataset and set the index to the institution name. Complete the following tasks:
# * Convert the median earnings within 10 years (md_earn_wne_p10) column to numeric
# * Create a column for the total SAT score
# * Select just the columns for SAT total, ugds, relaffil and md_earn_wne_p10 into another DataFrame called `college_samp`. Continue with this DataFrame for the rest of the problem.
# * Drop any rows with missing values
# * Randomly sample 10% of the DataFrame and assign it back to itself.
# * Call the `map` method on the `relaffil` column. Pass it a dictionary to convert the values to color names. Assign the result to the column `color`
# * Take the square root of the ugds column and assign it to the column `size`.
# * Create a scatterplot of the total SAT scores vs the md_earn_wne_p10 column. Color and size each point with their respective columns.
# * Extra Credit: Annotate the school with the largest population as it is done [in this example](https://matplotlib.org/users/annotations.html) </span>

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Read in the employee dataset and select the `salary` column as a Series, drop the missing values, and assign it to a variable. Read about the `pd.cut` function and create categories that span 25k from 0 to 300k. Save this result as a Series and find the frequency of each category. Then take that result and create a `pie` chart with labels.</span>
