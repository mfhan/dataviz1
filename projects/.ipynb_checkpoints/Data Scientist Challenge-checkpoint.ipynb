# %% [markdown]
# ## Data Scientist Challenge

# %% [markdown]
# In this challenge you are assuming the position of a data scientist for a large corporation with offices in many states. The company you work for is looking to gain insights from its data from across the many states that it does business over the course of the year 2014. The company runs many 'sales' over the course of the year in its states. The data you have is of the 10,000 different sales run in different states. Each sale lasts for a particular amount of time denoted by 'sale_start' and 'sale_end' columns. Along with each sale is the revenue for that particular sale.
#
# The company is primarily interested in determining what is happening to revenue over time and what strategy should be undertaken to maximize revenue.
#
# You don't need any advanced statistics for this assignment. Good exploration and visualizations will reveal everything you need to know about what is happening. Check out pandas time-series module documentation here - http://pandas.pydata.org/pandas-docs/stable/timeseries.html

# %% [markdown]
# Please fork the repository into your github profile, clone it and then start working on it locally.

# %%
# starter code
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sl = pd.read_csv('../../data/sales.csv', parse_dates=['sale_start', 'sale_end'])

# %%
sl = sl.drop(columns='sale_end')

# %%
sl.head()
# Out:
#       state sale_start  revenue
# 0  Arkansas 2014-12-24   1311.0
# 1   Florida 2014-10-15    698.0
# 2      Iowa 2014-09-07   1193.0
# 3   Indiana 2014-05-19    469.0
# 4     Maine 2014-04-19    334.0

# %%
sl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
# state         10000 non-null object
# sale_start    10000 non-null datetime64[ns]
# revenue       10000 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 234.5+ KB

# %%
sl.shape
# Out:
# (10000, 3)

# %%
st = sl['state']
st.head()
# Out:
# 0    Arkansas
# 1     Florida
# 2        Iowa
# 3     Indiana
# 4       Maine
# Name: state, dtype: object

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.countplot('state', data=sl, ax=ax)
ax

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.countplot('sale_start', data=sl, ax=ax)
ax

# %%
date = sl['sale_start'].sort_values()
rev = sl['revenue']
st = sl['state']
maxdate = date.max

# %%
lol= sl.groupby(['state', date]).agg({'revenue':'sum'}).reset_index()
lol
# Out:
#            state sale_start  revenue
# 0         Alaska 2014-01-01   2733.0
# 1         Alaska 2014-01-02    680.0
# 2         Alaska 2014-01-03   1479.0
# 3         Alaska 2014-01-04   1251.0
# 4         Alaska 2014-01-05   2123.0
# 5         Alaska 2014-01-06   1381.0
# 6         Alaska 2014-01-08   1332.0
# 7         Alaska 2014-01-09   3083.0
# 8         Alaska 2014-01-10    817.0
# 9         Alaska 2014-01-11    743.0
# 10        Alaska 2014-01-12    796.0
# 11        Alaska 2014-01-13   1602.0
# 12        Alaska 2014-01-14   3426.0
# 13        Alaska 2014-01-15    594.0
# 14        Alaska 2014-01-16   3412.0
# 15        Alaska 2014-01-17   2090.0
# 16        Alaska 2014-01-18   1306.0
# 17        Alaska 2014-01-19    723.0
# 18        Alaska 2014-01-20   2736.0
# 19        Alaska 2014-01-21   2014.0
# 20        Alaska 2014-01-22   1542.0
# 21        Alaska 2014-01-24   1232.0
# 22        Alaska 2014-01-25   1224.0
# 23        Alaska 2014-01-27    726.0
# 24        Alaska 2014-01-28   2202.0
# 25        Alaska 2014-01-29   3650.0
# 26        Alaska 2014-01-30    647.0
# 27        Alaska 2014-01-31   1308.0
# 28        Alaska 2014-02-01   1524.0
# 29        Alaska 2014-02-02   2475.0
# ...          ...        ...      ...
# 5437  Washington 2014-11-24   1519.0
# 5438  Washington 2014-11-25   2556.0
# 5439  Washington 2014-11-26   1642.0
# 5440  Washington 2014-11-27   1711.0
# 5441  Washington 2014-11-28   2415.0
# 5442  Washington 2014-11-29   1631.0
# 5443  Washington 2014-11-30   2309.0
# 5444  Washington 2014-12-01    898.0
# 5445  Washington 2014-12-02   1588.0
# 5446  Washington 2014-12-03    867.0
# 5447  Washington 2014-12-04    771.0
# 5448  Washington 2014-12-05   1485.0
# 5449  Washington 2014-12-06    838.0
# 5450  Washington 2014-12-07    844.0
# 5451  Washington 2014-12-09   1489.0
# 5452  Washington 2014-12-10   2388.0
# 5453  Washington 2014-12-11    729.0
# 5454  Washington 2014-12-13    750.0
# 5455  Washington 2014-12-14   1826.0
# 5456  Washington 2014-12-15   1568.0
# 5457  Washington 2014-12-16   1727.0
# 5458  Washington 2014-12-18   1715.0
# 5459  Washington 2014-12-19   2244.0
# 5460  Washington 2014-12-20   5065.0
# 5461  Washington 2014-12-21   2332.0
# 5462  Washington 2014-12-22   1581.0
# 5463  Washington 2014-12-23    774.0
# 5464  Washington 2014-12-24    613.0
# 5465  Washington 2014-12-25    872.0
# 5466  Washington 2014-12-26   1745.0
#
# [5467 rows x 3 columns]

# %%
date.head()
# Out:
# 0   2014-12-24
# 1   2014-10-15
# 2   2014-09-07
# 3   2014-05-19
# 4   2014-04-19
# Name: sale_start, dtype: datetime64[ns]

# %%
sl.head()
# Out:
#       state sale_start  revenue
# 0  Arkansas 2014-12-24   1311.0
# 1   Florida 2014-10-15    698.0
# 2      Iowa 2014-09-07   1193.0
# 3   Indiana 2014-05-19    469.0
# 4     Maine 2014-04-19    334.0

# %%
monthend = sl.groupby(pd.Grouper(key='sale_start', freq='1M')).agg({'revenue':'sum'}) 
monthend
# Out:
#              revenue
# sale_start
# 2014-01-31  537733.0
# 2014-02-28  534894.0
# 2014-03-31  576577.0
# 2014-04-30  618229.0
# 2014-05-31  770376.0
# 2014-06-30  707292.0
# 2014-07-31  765917.0
# 2014-08-31  846619.0
# 2014-09-30  838562.0
# 2014-10-31  925434.0
# 2014-11-30  922144.0
# 2014-12-31  833648.0

# %%
monthend.plot()

# %%
gr = pd.Grouper(key='sale_start', freq='1M')

# %%
sl.groupby(['state', gr]).agg({'revenue': 'mean'}).reset_index()
# Out:
#           state sale_start      revenue
# 0        Alaska 2014-01-31   699.283582
# 1        Alaska 2014-02-28   688.189189
# 2        Alaska 2014-03-31   688.363636
# 3        Alaska 2014-04-30   653.818182
# 4        Alaska 2014-05-31   630.636364
# 5        Alaska 2014-06-30   639.848485
# 6        Alaska 2014-07-31   610.323529
# 7        Alaska 2014-08-31   638.062500
# 8        Alaska 2014-09-30   605.360000
# 9        Alaska 2014-10-31   606.407407
# 10       Alaska 2014-11-30   605.888889
# 11       Alaska 2014-12-31   607.272727
# 12     Arkansas 2014-01-31  1445.000000
# 13     Arkansas 2014-02-28  1341.500000
# 14     Arkansas 2014-03-31  1371.000000
# 15     Arkansas 2014-04-30  1318.272727
# 16     Arkansas 2014-05-31  1292.192308
# 17     Arkansas 2014-06-30  1312.714286
# 18     Arkansas 2014-07-31  1264.250000
# 19     Arkansas 2014-08-31  1256.526316
# 20     Arkansas 2014-09-30  1221.431818
# 21     Arkansas 2014-10-31  1189.219512
# sale_start
# 2014-01-31        1424       786   670       606     794   1296        1021
# 2014-02-28        1223       781   663       553     783   1438        1003
# 2014-03-31        1322       795   672       578     774   1311        1010
# 2014-04-30        1261       757   682       566     755   1343        1027
# 2014-05-31        1189       758   651       540     738   1298         928
# 2014-06-30        1176       695   634       571     721   1267         945
# 2014-07-31        1179       739   602       541     723   1278         891
# 2014-08-31        1151       728   631       540     700   1239         900
# 2014-09-30        1132       692   594       550     713   1220         867
# 2014-10-31        1113       683   634       518     734   1189         849
# 2014-11-30        1083       677   582       476     667   1180         836
# 2014-12-31        1046       668   604       520     661   1142         807
#
# [12 rows x 25 columns]

# %%
sell.plot()

# %%
sell.plot(figsize=(16,10))

# %%
sellsum = sl.pivot_table(index = gr, columns = 'state', 
                      values = 'revenue', aggfunc='sum' ).astype(int)
sellsum
# Out:
# state       Alaska  Arkansas  California  Delaware  Florida  Georgia  Idaho  \
# sale_start
# 2014-01-31   46852      1445       57488      3252     5029     2867   4537
# 2014-02-28   50926     10732       34943      8061     8010    12975   5767
# 2014-03-31   37860      9597       34562      8723    10537    16705  15601
# 2014-04-30   35960     14501       32918     26431    13113    20010  20521
# 2014-05-31   34685     33597       23480     25922    23559    34602  38025
# 2014-06-30   21115     36756       26395     22443    33545    29898  33992
# 2014-07-31   20751     40456       19124     24870    32775    50998  46123
# 2014-08-31   20418     47748       20223     28133    37439    36247  45472
# 2014-09-30   15134     53743       11076     32588    31116    61039  44136
# 2014-10-31   16373     48758       11195     40397    50874    55053  56423
# 2014-11-30    5453     71756        9628     48074    43820    63785  74586
# 2014-12-31    6680     55059        7624     41745    39728    54191  62937
#
# state       Illinois  Indiana   Iowa     ...      Montana  Nebraska  Nevada  \
# sale_start                               ...
# 2014-01-31      1744    38614   3668     ...         3738     45514   26245
# 2014-02-28      9935    26023  10145     ...         4560     38359   28115
# 2014-03-31     27774    28274  11396     ...        17473     45913   27616
# 2014-04-30     26868    21643  20112     ...        14276     36721   17232
# 2014-05-31     38581    28692  34826     ...        27956     30006   17545
# 2014-06-30     49981    22341  29650     ...        21156     26334   21328
# 2014-07-31     43168    19619  44582     ...        27394     22396   13133
# 2014-08-31     63983    20309  45929     ...        37482     25463   10521
# 2014-09-30     57519    10255  52084     ...        37590     12260    8465
# 2014-10-31     76918    11764  56572     ...        52601     13984    6832
# 2014-11-30     56330     5691  45146     ...        39670      9119    5096
# 2014-12-31     83028     4454  60501     ...        40936      3169    1285
#
# state       New Mexico  New York   Ohio  Oklahoma  Oregon  Texas  Washington
# sale_start
# 2014-01-31        1424     56641  44284     44276   54839   1296        2042
# 2014-02-28        7343     46122  37831     34877   48568  10067        4015
# 2014-03-31       10581     50917  30251     31233   36390  14421       12123
# 2014-04-30       17658     43186  25928     27764   40054  26871       13363
# 2014-05-31       26177     35651  24094     26468   39894  36363       25061
# 2014-06-30       37659     25727  25390     22295   23095  32964       25524
# 2014-07-31       34206     32555  15673     17334   25316  51153       35674
# 2014-08-31       54100     20406  15791     15684   23106  48350       34212
# 2014-09-30       54344     17316  14869     11551   16402  57369       45990
# 2014-10-31       59038     20512   8878      7265   13956  61876       46744
# 2014-11-30       50911      9483  11065      5715   14679  73174       46817
# 2014-12-31       38735      5349   3624      5200    7943  79983       34709
#
# [12 rows x 25 columns]

# %%
sellsum.plot(figsize=(16,10))

# %%
mys = st.isin['California', 'Texas', 'Florida', 'New York']
mystate=st[mys]
mystate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-ad64898e9193> in <module>()
# ----> 1 mys = st.isin['California', 'Texas', 'Florida', 'New York']
#       2 mystate=st[mys]
#       3 mystate
#
# TypeError: 'method' object is not subscriptable

# %%
sell
sns.barplot(x='state', y='revenue', data=sl)

# %%
df1 = sl.groupby('monthend').agg({'revenue': ['mean']})
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-c4b779937b54> in <module>()
# ----> 1 df1 = sl.groupby('monthend').agg({'revenue': ['mean']})
#       2 df1
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'monthend'

# %%
sns.barplot(x='state', y='revenue', data=sl)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
aa = sns.barplot(x='sale_start' , y='revenue', data=sl)
aa
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sd.groupby

# %%
sl.groupby('state').agg({'state':'sum'})
# Out:
#                                                          state
# state
# Alaska       AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlas...
# Arkansas     ArkansasArkansasArkansasArkansasArkansasArkans...
# California   CaliforniaCaliforniaCaliforniaCaliforniaCalifo...
# Delaware     DelawareDelawareDelawareDelawareDelawareDelawa...
# Florida      FloridaFloridaFloridaFloridaFloridaFloridaFlor...
# Georgia      GeorgiaGeorgiaGeorgiaGeorgiaGeorgiaGeorgiaGeor...
# Idaho        IdahoIdahoIdahoIdahoIdahoIdahoIdahoIdahoIdahoI...
# Illinois     IllinoisIllinoisIllinoisIllinoisIllinoisIllino...
# Indiana      IndianaIndianaIndianaIndianaIndianaIndianaIndi...
# Iowa         IowaIowaIowaIowaIowaIowaIowaIowaIowaIowaIowaIo...
# Kansas       KansasKansasKansasKansasKansasKansasKansasKans...
# Louisiana    LouisianaLouisianaLouisianaLouisianaLouisianaL...
# Maine        MaineMaineMaineMaineMaineMaineMaineMaineMaineM...
# Mississippi  MississippiMississippiMississippiMississippiMi...
# Missouri     MissouriMissouriMissouriMissouriMissouriMissou...
# Montana      MontanaMontanaMontanaMontanaMontanaMontanaMont...
# Nebraska     NebraskaNebraskaNebraskaNebraskaNebraskaNebras...
# Nevada       NevadaNevadaNevadaNevadaNevadaNevadaNevadaNeva...
# New Mexico   New MexicoNew MexicoNew MexicoNew MexicoNew Me...
# New York     New YorkNew YorkNew YorkNew YorkNew YorkNew Yo...
# Ohio         OhioOhioOhioOhioOhioOhioOhioOhioOhioOhioOhioOh...
# Oklahoma     OklahomaOklahomaOklahomaOklahomaOklahomaOklaho...
# Oregon       OregonOregonOregonOregonOregonOregonOregonOreg...
# Texas        TexasTexasTexasTexasTexasTexasTexasTexasTexasT...
# Washington   WashingtonWashingtonWashingtonWashingtonWashin...

# %% [markdown]
# #hello notebook!
